# %% [markdown]
# <a href="https://colab.research.google.com/github/immy78/Deep_Learning/blob/master/Santander_Customer_Satisfaction_by_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import Sequential

# %%
from tensorflow.keras.layers import Conv1D,MaxPool1D,Flatten,Dense,BatchNormalization,Dropout

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f47455bc-d21c-4412-8bac-ed8463057797" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f47455bc-d21c-4412-8bac-ed8463057797">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Santander Bank dataset.zip to Santander Bank dataset.zip

# %%
import zipfile
import io
zf = zipfile.ZipFile(io.BytesIO(uploaded['Santander Bank dataset.zip']), "r")
zf.extractall()

# %%
df = pd.read_csv('/content/Santander Bank dataset/santandar_train.csv')
df.head()
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult3          var38  TARGET
# 0   1     2     23  ...                     0.0   39205.170000       0
# 1   3     2     34  ...                     0.0   49278.030000       0
# 2   4     2     23  ...                     0.0   67333.770000       0
# 3   8     2     37  ...                     0.0   64007.970000       0
# 4  10     2     39  ...                     0.0  117310.979016       0
#
# [5 rows x 371 columns]

# %%
 df.shape
# Out:
# (76020, 371)

# %%
 x = df.drop(['ID','TARGET'],axis=1)
 x.head()
# Out:
#    var3  var15  ...  saldo_medio_var44_ult3          var38
# 0     2     23  ...                     0.0   39205.170000
# 1     2     34  ...                     0.0   49278.030000
# 2     2     23  ...                     0.0   67333.770000
# 3     2     37  ...                     0.0   64007.970000
# 4     2     39  ...                     0.0  117310.979016
#
# [5 rows x 369 columns]

# %%
y = df['TARGET']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: TARGET, dtype: int64

# %%
sns.countplot(x ='TARGET',data=df)

# %%
df['TARGET'].value_counts()
# Out:
# 0    73012
# 1     3008
# Name: TARGET, dtype: int64

# %%
73012/(73012+3008)
# Out:
# 0.9604314654038411

# %%
x_train , x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0,stratify =y)

# %%
x_train.shape , x_test.shape
# Out:
# ((60816, 369), (15204, 369))

# %% [markdown]
# ### Remove constant,Quasi constaent and Duplicate_Feature

# %%
filter = VarianceThreshold(0.01)
x_train = filter.fit_transform(x_train)
x_test = filter.transform(x_test)

# %%
x_train.shape , x_test.shape
# Out:
# ((60816, 273), (15204, 273))
